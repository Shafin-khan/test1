# %%
# Home Price prediction

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Untitled Folder 2/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
new_df = df.drop('price',axis='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
# (1) Predict price of a home with area = 3300 sqr ft
reg.predict([[3300]])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# Y = m * X + b (m is coefficient and b is intercept


# Generate CSV file with list of home price predictions
area_df = pd.read_csv("areas.csv")
area_df.head(3)

# %% [markdown]
# # Ans of the given exercise

# %%
 
df2 = pd.read_csv("../Untitled Folder 2/canada_per_capita_income.csv")
# df2

# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('per capita income(US$)')
# plt.scatter(df2.year, df2.per capita income ,color='red',marker='*')
plt.scatter(df2.year,df2['per capita income (US$)'], color='red',marker='+')

# plt.show()

# %%
# Create linear regression object
new_df2 = df2.drop('per capita income (US$)', axis='columns')
# new_df2

income= df2['per capita income (US$)']
# income

# %%
reg2 = linear_model.LinearRegression()
reg2.fit(new_df2,income)
# Out:
# LinearRegression()

# %%
# (1) Predict price of a home with area = 3300 sqr ft
reg2.predict([[2050]])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66142.6463511])
